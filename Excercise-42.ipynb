# %% [markdown]
# <a href="https://colab.research.google.com/github/bidean/phpenv/blob/master/Excercise-42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total = 0
for i in range(0,5):
  number = int(input("Enter a number: "))
  confirm = input("Would you like to add this number to the total? ")
  if confirm == "yes":
    total = total + number
  else: total = total
print(total)
# Out:
# Enter a number: 5
# Would you like to add this number to the total? no
# Enter a number: 5
# Would you like to add this number to the total? yes
# Enter a number: 5
# Would you like to add this number to the total? no
# Enter a number: 5
# Would you like to add this number to the total? yes
# Enter a number: 5
# Would you like to add this number to the total? yes
# 15
